# %%
pip install Faker
# Out:
# Requirement already satisfied: Faker in C:\Users\juang\miniconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (40.21.0)
# Requirement already satisfied: tzdata in C:\Users\juang\miniconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from Faker) (2026.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
from faker import Faker

# %%
import random

# %%
# creamos una instancia faker
fake = Faker("es_MX")

# %%
datos = []
for i in range(100):
    datos.append({
        "Id_usuario": 1 + 1,
        "nombre": fake.name(),
        "correo": fake.email(),
        "edad": random.randint(18,65),
        "plataforma": random.choice(
            ["Tiktok", "Instagram", "Youtube"]
        )
    })

# %%
df = pd.DataFrame(datos)
df.head()
# Out:
#    Id_usuario                      nombre                          correo  \
# 0           2     Horacio Rosario Valadez           ricardo29@example.org
# 1           2        José Ramírez Aguirre          marcoscruz@example.net
# 2           2  Benito Jaime Urbina Dueñas        amadorsilvia@example.org
# 3           2        Reina Burgos Arreola         rolandocruz@example.com
# 4           2      Emilia Pineda Palomino  francisco-javier58@example.net
#
#    edad plataforma
# 0    39     Tiktok
# 1    40  Instagram
# 2    35     Tiktok
# 3    34    Youtube
# 4    60    Youtube

# %%
# exploracion del dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id_usuario  100 non-null    int64
#  1   nombre      100 non-null    str
#  2   correo      100 non-null    str
#  3   edad        100 non-null    int64
#  4   plataforma  100 non-null    str
# dtypes: int64(2), str(3)
# memory usage: 4.0 KB

# %%
# estadistica descriptiva
df.describe(include="all")
# Out:
#         Id_usuario                   nombre                 correo  \
# count        100.0                      100                    100
# unique         NaN                      100                    100
# top            NaN  Horacio Rosario Valadez  ricardo29@example.org
# freq           NaN                        1                      1
# mean           2.0                      NaN                    NaN
# std            0.0                      NaN                    NaN
# min            2.0                      NaN                    NaN
# 25%            2.0                      NaN                    NaN
# 50%            2.0                      NaN                    NaN
# 75%            2.0                      NaN                    NaN
# max            2.0                      NaN                    NaN
#
#               edad plataforma
# count   100.000000        100
# unique         NaN          3
# top            NaN  Instagram
# freq           NaN         38
# mean     41.560000        NaN
# std      14.078654        NaN
# min      18.000000        NaN
# 25%      30.750000        NaN
# 50%      41.500000        NaN
# 75%      53.250000        NaN
# max      63.000000        NaN

# %%
# Importar librerias para graficar 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Distribucion de edades
plt .figure(figsize=(8,4))
sns.histplot(
    df["edad"],
    bins=10
)
plt.title("Distribución de edades")
plt.show()

# %%
df_sucio = df.copy()

# %%
# le colocamos valores nulos
for i in random.sample(range(len(df_sucio)),5):
    df_sucio.loc[i,"nombre"] = None

# %%
df_sucio.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id_usuario  100 non-null    int64
#  1   nombre      95 non-null     str
#  2   correo      100 non-null    str
#  3   edad        100 non-null    int64
#  4   plataforma  100 non-null    str
# dtypes: int64(2), str(3)
# memory usage: 4.0 KB

# %%
# Edades invalidas
for i in random.sample(range(len(df_sucio)),5):
    df_sucio.loc[i,"edad"] = -10

# %%
df_sucio.describe()["edad"]
# Out:
# count    100.000000
# mean      38.990000
# std       17.868484
# min      -10.000000
# 25%       28.000000
# 50%       39.500000
# 75%       52.250000
# max       63.000000
# Name: edad, dtype: float64

# %%
# Seguidores imposibles
for i in random.sample(range(len(df_sucio)),5):
    df_sucio.loc[i,"seguidores"] = 5000000

# %%
df_sucio.describe()["seguidores"]
# Out:
# count          5.0
# mean     5000000.0
# std            0.0
# min      5000000.0
# 25%      5000000.0
# 50%      5000000.0
# 75%      5000000.0
# max      5000000.0
# Name: seguidores, dtype: float64

# %%
# Correos invalidos
for i in random.sample(range(len(df_sucio)),5):
    df_sucio.loc[i,"correo"] = "correo_invalido"

# %%
df_sucio.describe(include=["str", "object"])
# Out:
#                          nombre           correo plataforma
# count                        95              100        100
# unique                       95               96          3
# top     Horacio Rosario Valadez  correo_invalido  Instagram
# freq                          1                5         38
