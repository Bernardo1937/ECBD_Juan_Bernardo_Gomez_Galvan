# %%
import pandas as pd
import random

# %%
cantidad = 1000000

# %%
# Listas con datos aleatorios de Instagram para Cancún
influencers = ["@CancunVibes", "@PlayaLifeMX", "@RutaMaya", "@LifestyleCaribe", "@TurismoQROO", "@AventuraTulum", "@SolYArena", "@ViajeroMexicano"]
tipos_post = ["Turismo", "Playa", "Lifestyle", "Gastronomia", "Vida Nocturna"]
